# %% [markdown]
# <a href="https://colab.research.google.com/github/nhlanhlaNB/GoosebumpUI/blob/main/HousePricingRegressionModel1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import tarfile
import urllib.request

# %%
def load_housing_data():
  tarball_path = Path("datasets/housing.tgz")
  if not tarball_path.is_file():
    Path("datasets").mkdir(parents=True, exist_ok=True)
    url = "https://github.com/ageron/data/raw/main/housing.tgz"
    urllib.request.urlretrieve(url, tarball_path)
    with tarfile.open(tarball_path) as housing_tarball:
      housing_tarball.extractall(path="datasets")
  return pd.read_csv(Path("datasets/housing/csv"))

  house = load_housing_data()
  house.head()

# %%
# prompt: get housing information

import pandas as pd
import numpy as np
from pathlib import Path
import tarfile
import urllib.request

def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="datasets")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

housing = load_housing_data()
housing.sample(50)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1151     -121.84     37.34                33.0       1019.0           191.0
# 13211    -119.03     35.34                34.0       2221.0           436.0
# 8932     -122.48     37.76                48.0       2304.0           558.0
# 15798    -121.42     38.55                35.0        182.0            39.0
# 20083    -122.08     37.64                23.0       1897.0           440.0
# 15583    -117.21     34.11                26.0       1757.0           304.0
# 15193    -118.32     34.01                44.0       4032.0           913.0
# 433      -117.18     33.16                15.0       5923.0          1206.0
# 16753    -118.17     33.98                41.0        428.0           111.0
# 12872    -118.17     33.77                45.0       2143.0           697.0
# 16224    -118.96     36.49                24.0       1268.0           269.0
# ...
